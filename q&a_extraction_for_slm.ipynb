# %%
# !pip install pyPDF2
# Out:
# Requirement already satisfied: pyPDF2 in /usr/local/lib/python3.12/dist-packages (3.0.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from PyPDF2 import PdfReader

reader=PdfReader(stream=r"/content/drive/MyDrive/Fed_Meta_Allign.pdf")

text=""

for page in reader.pages:

  text+=page.extract_text()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter=RecursiveCharacterTextSplitter(separators=["\n\n","\n"],chunk_size=500,chunk_overlap=50)

splitted=splitter.split_text(text=text)

# %%
# !pip install langchain_google_genai
# Out:
# Requirement already satisfied: langchain_google_genai in /usr/local/lib/python3.12/dist-packages (2.1.12)
# Requirement already satisfied: langchain-core>=0.3.75 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (0.3.78)
# Requirement already satisfied: google-ai-generativelanguage<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (2.11.10)
# Requirement already satisfied: filetype<2,>=1.2 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (2.25.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (5.29.5)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.75->langchain_google_genai) (0.4.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.75->langchain_google_genai) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.75->langchain_google_genai) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.75->langchain_google_genai) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.75->langchain_google_genai) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.75->langchain_google_genai) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->langchain_google_genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->langchain_google_genai) (0.4.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (2.32.4)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (1.75.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (4.9.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.3.75->langchain_google_genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.75->langchain_google_genai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.75->langchain_google_genai) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.75->langchain_google_genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.75->langchain_google_genai) (0.25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.75->langchain_google_genai) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.75->langchain_google_genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.75->langchain_google_genai) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.75->langchain_google_genai) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.75->langchain_google_genai) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain_google_genai) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.75->langchain_google_genai) (1.3.1)

# %%
import google.generativeai as genai
from google.colab import userdata

# Configure Gemini
genai.configure(api_key=userdata.get('google'))
model = genai.GenerativeModel('models/gemma-3-27b-it')

def generate_qa_pairs(text):
    prompt = f"""
    You are a Technical AI Assistant specialized in Federated Learning and TinyML.
    Based on the text below, generate exactly 3 Question and Answer pairs about Fed-Meta-Align.

    TEXT: {text}

    Generate in this format:
    Q1: [Specific technical question]
    A1: [Brief 2-3 line answer]

    Q2: [Specific technical question]
    A2: [Brief 2-3 line answer]

    Q3: [Specific technical question]
    A3: [Brief 2-3 line answer]
    """

    try:
        response = model.generate_content(prompt)
        return response.text
    except Exception as e:
        return f"Error: {str(e)}"

# Process batches
all_outputs = []
for index, sentence in enumerate(splitted):
    print(f"Processing Batch-{index+1}/{len(splitted)}...")

    try:
        if sentence.strip() and len(sentence) > 50:  # Only process meaningful text
            response = generate_qa_pairs(sentence)
            all_outputs.append(response)
            print(f"Batch-{index+1} processing done.")
            print(f"Preview: {response[:100]}...")
        else:
            print(f"Batch-{index+1} skipped - too short")
            all_outputs.append("")

    except Exception as e:
        print(f"Batch-{index+1} processing failed: {e}")
        all_outputs.append("")
# Out:
# Processing Batch-1/95...
# Batch-1 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-2/95...
# Batch-2 processing done.
# Preview: Q1: What is the primary goal of the Fed-Meta-Align framework as described in the text?
# A1: Fed-Meta-...
# Processing Batch-3/95...
# Batch-3 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-4/95...
# Batch-4 processing done.
# Preview: Q1: What is the reported average test accuracy of Fed-Meta-Align across heterogeneous IoT devices?
# A...
# Processing Batch-5/95...
# Batch-5 processing done.
# Preview: Okay, here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided (limited) tex...
# Processing Batch-6/95...
# Batch-6 processing done.
# Preview: Please provide the text about Fed-Meta-Align. The provided text only discusses TinyML generally and ...
# Processing Batch-7/95...
# Batch-7 processing done.
# Preview: Okay, I see the provided text focuses on TinyML and its benefits, and mentions Dr. Mayukha Pal's wor...
# Processing Batch-8/95...
# Batch-8 processing done.
# Preview: Okay, here are 3 Question and Answer pairs about Federated Learning, based on the provided text, for...
# Processing Batch-9/95...
# Batch-9 processing done.
# Preview: Here are 3 Question and Answer pairs about Federated Learning, based on the provided text, focusing ...
# Processing Batch-10/95...
# Batch-10 processing done.
# Preview: Okay, here are 3 Question and Answer pairs about the challenges addressed by Fed-Meta-Align, based o...
# Processing Batch-11/95...
# Batch-11 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What spe...
# Processing Batch-12/95...
# Batch-12 processing done.
# Preview: Q1: What is the primary goal of the Fed-Meta-Align framework, and for what type of application is it...
# Processing Batch-13/95...
# Batch-13 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-14/95...
# Batch-14 processing done.
# Preview: Q1: What is the core idea behind the personalization phase in Fed-Meta-Align?
# A1: Fed-Meta-Align per...
# Processing Batch-15/95...
# Batch-15 processing done.
# Preview: Q1: What are the two main components of the Fed-Meta-Align framework for addressing client drift?
# A1...
# Processing Batch-16/95...
# Batch-16 processing done.
# Preview: Q1: What are the primary Federated Learning baselines that Fed-Meta-Align is shown to outperform?
# A1...
# Processing Batch-17/95...
# Batch-17 processing done.
# Preview: Q1: What is the primary focus of the Fed-Meta-Align framework as indicated by the text?
# A1: Fed-Meta...
# Processing Batch-18/95...
# Batch-18 processing done.
# Preview: Q1: What is the foundational baseline algorithm used in Federated Learning, as mentioned in the text...
# Processing Batch-19/95...
# Batch-19 processing done.
# Preview: Q1: What is the primary challenge hindering the effectiveness of Federated Learning in real-world sc...
# Processing Batch-20/95...
# Batch-20 processing done.
# Preview: Q1: What is the primary goal of the initial "Meta-Initialized Model" (w*) phase in Fed-Meta-Align, a...
# Processing Batch-21/95...
# Batch-21 processing done.
# Preview: Okay, here are 3 Question and Answer pairs about techniques related to addressing challenges in Fede...
# Processing Batch-22/95...
# Batch-22 processing done.
# Preview: Q1: What is the primary inspiration behind the initialization strategy used in Fed-Meta-Align?
# A1: F...
# Processing Batch-23/95...
# Batch-23 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-24/95...
# Batch-24 processing done.
# Preview: Q1: What is the core strategy employed by Fed-Meta-Align to improve federated learning performance?
# ...
# Processing Batch-25/95...
# Batch-25 processing done.
# Preview: Q1: What are the primary benefits of applying Federated Learning (FL) techniques in conjunction with...
# Processing Batch-26/95...
# Batch-26 processing done.
# Preview: Q1: What is a key benefit of using Fed-Meta-Align in IoT fault classification compared to traditiona...
# Processing Batch-27/95...
# Batch-27 processing done.
# Preview: Q1: What gap in existing research does this work aim to address regarding Federated Learning?
# A1: Th...
# Processing Batch-28/95...
# Batch-28 processing done.
# Preview: Okay, here are 3 Question and Answer pairs about Federated Averaging (FedAvg), based solely on the p...
# Processing Batch-29/95...
# Batch-29 processing done.
# Preview: Q1: What is the primary limitation of the FedAvg algorithm discussed in the text?
# A1: FedAvg assumes...
# Processing Batch-30/95...
# Batch-30 processing done.
# Preview: Q1: How does FedProx attempt to mitigate client drift during Federated Learning?
# A1: FedProx adds a ...
# Processing Batch-31/95...
# Batch-31 processing done.
# Preview: Q1: What are the primary challenges that Fed-Meta-Align is designed to overcome in IoT fault classif...
# Processing Batch-32/95...
# Batch-32 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-33/95...
# Batch-33 processing done.
# Preview: Q1: What is the main purpose of the foundational model initialization phase (Phase 0) in Fed-Meta-Al...
# Processing Batch-34/95...
# Batch-34 processing done.
# Preview: Here are 3 Question and Answer pairs about the foundational model initialization (Phase 0) described...
# Processing Batch-35/95...
# Batch-35 processing done.
# Preview: Q1: What is the purpose of the initial training loop (epochs 1 to Edo) described in the text?
# A1: Th...
# Processing Batch-36/95...
# Batch-36 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-37/95...
# Batch-37 processing done.
# Preview: Q1: What is the primary goal of the Serial Meta-Initialization phase in Fed-Meta-Align?
# A1: The goal...
# Processing Batch-38/95...
# Batch-38 processing done.
# Preview: Q1: How is the training data partitioned during the meta-initialization phase of Fed-Meta-Align?
# A1:...
# Processing Batch-39/95...
# Batch-39 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: How does...
# Processing Batch-40/95...
# Batch-40 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-41/95...
# Batch-41 processing done.
# Preview: Q1: What is the primary goal of the communication rounds described in the text regarding the global ...
# Processing Batch-42/95...
# Batch-42 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-43/95...
# Batch-43 processing done.
# Preview: Q1: What optimization algorithm is used to update the model weights locally on the IoT device in Fed...
# Processing Batch-44/95...
# Batch-44 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-45/95...
# Batch-45 processing done.
# Preview: Q1: How does Fed-Meta-Align quantify the quality of an IoT device's update using the query loss (LQ)...
# Processing Batch-46/95...
# Batch-46 processing done.
# Preview: Q1: What information does each IoT device transmit to the central server during the Federated Learni...
# Processing Batch-47/95...
# Batch-47 processing done.
# Preview: Q1: How does Fed-Meta-Align quantify the alignment of an individual IoT device's update with the glo...
# Processing Batch-48/95...
# Batch-48 processing done.
# Preview: Q1: How does the Fed-Meta-Align server determine the weight assigned to each IoT device?
# A1: The ser...
# Processing Batch-49/95...
# Batch-49 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-50/95...
# Batch-50 processing done.
# Preview: Q1: What is the purpose of computing the 'query score' (st) in the Fed-Meta-Align process, and how i...
# Processing Batch-51/95...
# Batch-51 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: How are ...
# Processing Batch-52/95...
# Batch-52 processing done.
# Preview: Q1: What is the role of the 'rateα' and the update equation ϕr+1=ϕr+αX t∈Crˆwt∆r t in the federated ...
# Processing Batch-53/95...
# Batch-53 processing done.
# Preview: Q1: How does Fed-Meta-Align approach personalization after global model training (Phases 1 & 2)?
# A1:...
# Processing Batch-54/95...
# Batch-54 processing done.
# Preview: Q1: What portion of the global model’s layers are frozen during the personalized fine-tuning stage i...
# Processing Batch-55/95...
# Batch-55 processing done.
# Preview: Q1: What is the purpose of the 'rateγ' update step in Fed-Meta-Align, and what variables are involve...
# Processing Batch-56/95...
# Batch-56 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-57/95...
# Batch-57 processing done.
# Preview: Q1: What is the primary purpose of Algorithm 4 in the context of Fed-Meta-Align?
# A1: Algorithm 4 rep...
# Processing Batch-58/95...
# Batch-58 processing done.
# Preview: Q1: What is the primary goal of the experiments conducted to validate Fed-Meta-Align?
# A1: The experi...
# Processing Batch-59/95...
# Batch-59 processing done.
# Preview: Q1: What is the initial state of the personalized model (ϕt,pers) on each IoT device, and from where...
# Processing Batch-60/95...
# Batch-60 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What por...
# Processing Batch-61/95...
# Batch-61 processing done.
# Preview: Q1: What datasets are utilized in the Fed-Meta-Align approach, and what is the purpose of each?
# A1: ...
# Processing Batch-62/95...
# Batch-62 processing done.
# Preview: Okay, here are 3 Question and Answer pairs about the provided text, focusing on the context of poten...
# Processing Batch-63/95...
# Batch-63 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What typ...
# Processing Batch-64/95...
# Batch-64 processing done.
# Preview: Q1: What percentage of the total training data is allocated to the Serial Meta-Initialization phase ...
# Processing Batch-65/95...
# Batch-65 processing done.
# Preview: Okay, here are 3 Question and Answer pairs about Fed-Meta-Align, based solely on the provided text, ...
# Processing Batch-66/95...
# Batch-66 processing done.
# Preview: Q1: What is the primary goal of using device-specific datasets in Fed-Meta-Align?
# A1: The goal is to...
# Processing Batch-67/95...
# Batch-67 processing done.
# Preview: Q1: What is the input feature dimensionality for the Fed-Meta-Align model described in the text?
# A1:...
# Processing Batch-68/95...
# Batch-68 processing done.
# Preview: Here are 3 Question and Answer pairs about the baselines used in comparison to Fed-Meta-Align, based...
# Processing Batch-69/95...
# Batch-69 processing done.
# Preview: Q1: What performance difference is observed between FedAvg's Global Model and its personalized versi...
# Processing Batch-70/95...
# Batch-70 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-71/95...
# Batch-71 processing done.
# Preview: Q1: What optimization algorithm and learning rate were used for training the models in this Fed-Meta...
# Processing Batch-72/95...
# Batch-72 processing done.
# Preview: Q1: How many communication rounds were used in the Parallel Federated Learning (FL) phase of the Fed...
# Processing Batch-73/95...
# Batch-73 processing done.
# Preview: Q1: What is the main purpose of the Fed-Meta-Align framework, according to the text?
# A1: The Fed-Met...
# Processing Batch-74/95...
# Batch-74 processing done.
# Preview: Here are 3 Question and Answer pairs about the described scenario, focusing on the issues highlighte...
# Processing Batch-75/95...
# Batch-75 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What are...
# Processing Batch-76/95...
# Batch-76 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-77/95...
# Batch-77 processing done.
# Preview: Q1: What are the two key components of the Fed-Meta-Align approach that contribute to its improved p...
# Processing Batch-78/95...
# Batch-78 processing done.
# Preview: Q1: What are the three key stages within the Fed-Meta-Align framework used for performance evaluatio...
# Processing Batch-79/95...
# Batch-79 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-80/95...
# Batch-80 processing done.
# Preview: Q1: What is the primary benefit of converting from Keras (FP32) to TFLite (UINT8) on IoT devices, ac...
# Processing Batch-81/95...
# Batch-81 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: How does...
# Processing Batch-82/95...
# Batch-82 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-83/95...
# Batch-83 processing done.
# Preview: Q1: What precision formats were used to evaluate the deployment efficiency of the Fed-Meta-Align mod...
# Processing Batch-84/95...
# Batch-84 processing done.
# Preview: Q1: How is the speedup percentage calculated when comparing a Keras (FP32) model to a TFLite (UINT8)...
# Processing Batch-85/95...
# Batch-85 processing done.
# Preview: Q1: What is the primary benefit of applying post-training quantization in the context of Fed-Meta-Al...
# Processing Batch-86/95...
# Batch-86 processing done.
# Preview: Q1: What are the two primary benefits of quantization as applied to models for deployment on IoT dev...
# Processing Batch-87/95...
# Batch-87 processing done.
# Preview: Q1: What is the primary goal of the Fed-Meta-Align framework?
# A1: Fed-Meta-Align is designed for rob...
# Processing Batch-88/95...
# Batch-88 processing done.
# Preview: Q1: What is the initial step in the Fed-Meta-Align process and why is it important?
# A1: The process ...
# Processing Batch-89/95...
# Batch-89 processing done.
# Preview: Here are 3 Question and Answer pairs about Fed-Meta-Align, based on the provided text:
#
# Q1: What is ...
# Processing Batch-90/95...
# Batch-90 processing done.
# Preview: Q1: What is the primary focus of the work described in the text regarding federated learning?
# A1: Th...
# Processing Batch-91/95...
# Batch-91 processing done.
# Preview: Please provide the text about Fed-Meta-Align. The provided text snippet only contains citations rela...
# Processing Batch-92/95...
# Batch-92 processing done.
# Preview: Please provide the text about Fed-Meta-Align. The provided text snippet only contains citations and ...
# Processing Batch-93/95...
# Batch-93 processing done.
# Preview: Please provide the text about Fed-Meta-Align. The provided text only contains citations to other pap...
# Processing Batch-94/95...
# Batch-94 processing done.
# Preview: Okay, I see the provided text snippets. However, the text *does not contain information about "Fed-M...
# Processing Batch-95/95...
# Batch-95 processing done.
# Preview: Okay, here are 3 Question and Answer pairs about Fed-Meta-Align, based *solely* on the provided text...

# %%
import re

qa_pairs = []

pattern = re.compile(r"(Q\d*:\s*(.*?))\n(A\d*:\s*(.*?))(?=\nQ|\Z)", re.DOTALL)

for index,text in enumerate(all_outputs):
    matches = pattern.findall(text)
    for q_full, q, a_full, a in matches:
        qa_pairs.append((q_full.strip(), a_full.strip()))

with open("filtered_qna.txt", "w") as f:
    for q, a in qa_pairs:
        f.write(f"{q}\n{a}\n\n")

print(f"Extracted {len(qa_pairs)} Q&A pairs and saved to 'filtered_qna.txt'")
# Out:
# Extracted 273 Q&A pairs and saved to 'filtered_qna.txt'
